# %% [markdown]
# <a href="https://colab.research.google.com/github/piyu0812/first/blob/main/KMeans_Problem_Satement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Mall_Customers.csv')
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
Male=df[df['Gender']=='Male']
Male
# Out:
#      CustomerID Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1   Male   19                  15                      39
# 1             2   Male   21                  15                      81
# 8             9   Male   64                  19                       3
# 10           11   Male   67                  19                      14
# 14           15   Male   37                  20                      13
# ..          ...    ...  ...                 ...                     ...
# 187         188   Male   28                 101                      68
# 192         193   Male   33                 113                       8
# 197         198   Male   32                 126                      74
# 198         199   Male   32                 137                      18
# 199         200   Male   30                 137                      83
#
# [88 rows x 5 columns]

# %%
Female=df[df['Gender']=='Female']
Female
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# ..          ...     ...  ...                 ...                     ...
# 191         192  Female   32                 103                      69
# 193         194  Female   38                 113                      91
# 194         195  Female   47                 120                      16
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
#
# [112 rows x 5 columns]

# %%
counts=df['Gender'].value_counts()
counts
# Out:
# Gender
# Female    112
# Male       88
# Name: count, dtype: int64

# %%
plt.pie(counts, labels=counts.index, colors=['red', 'yellow'], autopct='%1.1f%%', startangle=90)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.axis('equal')
plt.title('Percentage of Males and Females')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df=pd.read_csv('Mall_Customers.csv')
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
age=df[['Age']]
age
# Out:
#      Age
# 0     19
# 1     21
# 2     20
# 3     23
# 4     31
# ..   ...
# 195   35
# 196   45
# 197   32
# 198   32
# 199   30
#
# [200 rows x 1 columns]

# %%
clusters=4
kmeans=KMeans(n_clusters=clusters)
kmeans.fit(age)
centroid=kmeans.cluster_centers_
labels=kmeans.labels_
plt.scatter(age,[0]*len(data),c=labels)
plt.scatter(centroid,[0]*len(centroid),c='red',marker='*')
plt.xlabel('Age')
plt.title('K-means Clustering of Age')
plt.show()
print('cluster centers=')
for i, j in enumerate(centroid):
  print(f"Cluster {i}: {j[0]}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# cluster centers=
# Cluster 0: 22.599999999999987
# Cluster 1: 63.27586206896551
# Cluster 2: 34.229729729729726
# Cluster 3: 48.34042553191489

# %%
annual=df[['Annual Income (k$)']]
annual
# Out:
#      Annual Income (k$)
# 0                    15
# 1                    15
# 2                    16
# 3                    16
# 4                    17
# ..                  ...
# 195                 120
# 196                 126
# 197                 126
# 198                 137
# 199                 137
#
# [200 rows x 1 columns]

# %%
k=KMeans(n_clusters=4)
k.fit(annual)
center=k.cluster_centers_
l=k.labels_
plt.scatter(annual,[0]*len(df),c=l)
plt.scatter(center,[0]*len(center),c='red',marker='*')
plt.xlabel('Annual income(k$)')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Text(0.5, 0, 'Annual income(k$)')

# %%
spending=df[['Spending Score (1-100)']]
spending
km=KMeans(n_clusters=4)
km.fit(spending)
ct=km.cluster_centers_
lb=km.labels_
plt.scatter(spending,[0]*len(df),c=lb)
plt.scatter(ct,[0]*len(ct),c='red',marker='*')
plt.xlabel('Spending Score')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Text(0.5, 0, 'Spending Score')

# %% [markdown]
# Perform clustering on Age and spending score

# %%
df1=pd.read_csv('Mall_Customers.csv')
df1
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
a_s=df1[['Age','Spending Score (1-100)']]
a_s
# Out:
#      Age  Spending Score (1-100)
# 0     19                      39
# 1     21                      81
# 2     20                       6
# 3     23                      77
# 4     31                      40
# ..   ...                     ...
# 195   35                      79
# 196   45                      28
# 197   32                      74
# 198   32                      18
# 199   30                      83
#
# [200 rows x 2 columns]

# %%
wcc=[]
for i in range(1,10):
  kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
  kmeans.fit(a_s)
  wcc.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(range(1,10),wcc)

# %% [markdown]
# Here we find that the efficient clusters is 4

# %%
x=a_s.iloc[:,:].values
kmeans=KMeans(n_clusters=4, init='k-means++',random_state=42)
y=kmeans.fit_predict(x)
y
centroid=kmeans.cluster_centers_
centroid
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([[55.70833333, 48.22916667],
#        [43.29166667, 15.02083333],
#        [30.1754386 , 82.35087719],
#        [27.61702128, 49.14893617]])

# %%
plt.scatter(x[y==0,0],x[y==0,1],color='red')
plt.scatter(x[y==1,0],x[y==1,1],color='green')
plt.scatter(x[y==2,0],x[y==2,1],color='blue')
plt.scatter(x[y==3,0],x[y==3,1],color='black')
plt.xlabel('Age')
plt.ylabel('Spending Score')
plt.scatter(centroid[:, 0], centroid[:, 1], marker='X', s=200, c='cyan')
